# %% [markdown]
# <a href="https://colab.research.google.com/github/Annamjohn/Python/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=[1,5,2]
print(pd.Series(a))
print(a[1])
# Out:
# 0    1
# 1    5
# 2    2
# dtype: int64
# 5

# %%
b=pd.Series(a,index=['a','b','c'])
print(b)
print(b['c'])
# Out:
# a    1
# b    5
# c    2
# dtype: int64
# 2

# %%
c={'day1':"math",'day2':"science",'day3':'pe'}
d=pd.Series(c)
print(d)
# Out:
# day1       math
# day2    science
# day3         pe
# dtype: object

# %%
e=pd.Series(c,index=['day1','day3'])
print(e)
# Out:
# day1    math
# day3      pe
# dtype: object

# %%
data={'fruit':['apple','orange','watermelon'],
      'price':[40,55,80],'name':['Abi','Gang','Fruity']}
df=pd.DataFrame(data)
# print(df) 
print(df.head())   
# print(df.tail())  
# print(df.info())
# Out:
#         fruit  price    name
# 0       apple     40     Abi
# 1      orange     55    Gang
# 2  watermelon     80  Fruity

# %%
print(df.loc[1]) #row index
# Out:
# fruit    orange
# price        55
# name       Gang
# Name: 1, dtype: object

# %%
print(df.loc[[0,2]])
# Out:
#         fruit  price    name
# 0       apple     40     Abi
# 2  watermelon     80  Fruity

# %%
print(df.to_string()) #displays entire dataframe
# Out:
#         fruit  price    name
# 0       apple     40     Abi
# 1      orange     55    Gang
# 2  watermelon     80  Fruity

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
pd.read_json

# %%
df=pd.read_csv("/content/heart.csv")
df.plot()
plt.show()

# %%
df.plot(kind='scatter',x='thal',y='target')
plt.show()

# %%
df['target'].plot(kind='hist')
plt.show()

# %%
df.plot(kind='bar',x='thal',y='target')
# Out:
# <Axes: xlabel='thal'>
